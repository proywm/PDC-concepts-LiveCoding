# %% [markdown]
# <a href="https://colab.research.google.com/github/proywm/PDC-concepts-LiveCoding/blob/main/LiveCoding_Concurrency_Simulating_Transportation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
import time
from IPython.display import clear_output

# Setup
total_passengers = 10
bus_capacity = 1
total_trips = 0
passengers_transported = 0
trip_details = []

def print_smileys(count, total_slots=20):
    smileys = "😃" * count + "⬜" * (total_slots - count)
    smiley_grid = []
    for i in range(2):  # Always print a 4x5 grid
        smiley_grid.append(smileys[i*5:(i+1)*5])
    return smiley_grid

# Sequential Transport Function
def transport_passengers(total_passengers, bus_capacity):
    global total_trips, passengers_transported
    while passengers_transported < total_passengers:
        total_trips += 1
        passengers_transported += bus_capacity
        if passengers_transported > total_passengers:
            passengers_transported = total_passengers
        trip_details.append((total_trips, passengers_transported))
        visualize_trip(total_trips, passengers_transported)
        time.sleep(1)

# Visualization
def visualize_trip(trip_number, passengers_transported):
    clear_output(wait=True)
    num_smileys_start = total_passengers - passengers_transported
    num_smileys_stop = passengers_transported
    fixed_path_segment = "-" * 10  # Each segment between start, intermediate, and stop

    start_smileys = print_smileys(num_smileys_start)
    stop_smileys = print_smileys(num_smileys_stop)

    # Visualization for the journey from Start to Stop with intermediate steps
    bus_path_1 = "🚗" + fixed_path_segment + fixed_path_segment + fixed_path_segment
    bus_path_2 = fixed_path_segment + "🚗" + fixed_path_segment + fixed_path_segment
    bus_path_3 = fixed_path_segment + fixed_path_segment + "🚗" + fixed_path_segment
    bus_path_4 = fixed_path_segment + fixed_path_segment + fixed_path_segment + "🚗"

    placeholder = " " * (len(fixed_path_segment) * 3 + 3)

    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + bus_path_1 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + bus_path_2 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + bus_path_3 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + bus_path_4 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    print(f"Throughput: {passengers_transported / trip_number:.2f} passengers per trip")
    print()
    # Simulate the return of the bus
    time.sleep(0.25)
    clear_output(wait=True)
    return_path_4 = "🚗" + fixed_path_segment + fixed_path_segment + fixed_path_segment
    return_path_3 = fixed_path_segment + "🚗" + fixed_path_segment + fixed_path_segment
    return_path_2 = fixed_path_segment + fixed_path_segment + "🚗" + fixed_path_segment
    return_path_1 = fixed_path_segment + fixed_path_segment + fixed_path_segment + "🚗"

    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + return_path_1 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + return_path_2 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + return_path_3 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported.")
    for row in range(2):
        if row == 1:
            print(start_smileys[row] + "  " + return_path_4 + "  " + stop_smileys[row])
        else:
            print(start_smileys[row] + "  " + placeholder + "  " + stop_smileys[row])
    print(f"Throughput: {passengers_transported / trip_number:.2f} passengers per trip")
    print()

# Run the transportation
transport_passengers(total_passengers, bus_capacity)
# Out:
# Trip 10: 10 passengers transported.
# ⬜⬜⬜⬜⬜                                     😃😃😃😃😃
# ⬜⬜⬜⬜⬜  🚗------------------------------  😃😃😃😃😃
# Throughput: 1.00 passengers per trip

# %%
import time
import threading
from IPython.display import clear_output

# Setup
total_passengers = 10
bus_capacity = 1
total_trips = 0
passengers_transported = 0
trip_details = []
lock = threading.Lock()

def print_smileys(count, total_slots=10):
    smileys = "😃" * count + "⬜" * (total_slots - count)
    smiley_grid = []
    for i in range(2):  # Always print a 2x5 grid
        smiley_grid.append(smileys[i*5:(i+1)*5])
    return smiley_grid

# Transport function for a single car
def transport_passengers(car_id, car_emoji, lane, start_delay=0):
    global total_trips, passengers_transported
    time.sleep(start_delay)  # Start delay for the second car
    while True:
        with lock:
            if passengers_transported >= total_passengers:
                break
            total_trips += 1
            passengers_transported += bus_capacity
            if passengers_transported > total_passengers:
                passengers_transported = total_passengers
            trip_details.append((total_trips, passengers_transported))
            visualize_trip(total_trips, passengers_transported, car_emoji, lane)
        time.sleep(1)

# Visualization
def visualize_trip(trip_number, passengers_transported, car_emoji, lane):
    clear_output(wait=True)
    num_smileys_start = total_passengers - passengers_transported
    num_smileys_stop = passengers_transported
    fixed_path_segment = "-" * 10  # Each segment between start, intermediate, and stop

    start_smileys = print_smileys(num_smileys_start)
    stop_smileys = print_smileys(num_smileys_stop)

    # Visualization for the journey from Start to Stop with intermediate steps
    if lane == 0:
        bus_path_1 = fixed_path_segment + car_emoji + fixed_path_segment + fixed_path_segment
        bus_path_2 = fixed_path_segment + fixed_path_segment[:5] + car_emoji + fixed_path_segment[5:]
        bus_path_3 = fixed_path_segment[:5] + car_emoji + fixed_path_segment + fixed_path_segment[5:]
        bus_path_4 = car_emoji + fixed_path_segment + fixed_path_segment + fixed_path_segment
    else:
        bus_path_1 = " " * len(fixed_path_segment) + fixed_path_segment + car_emoji + fixed_path_segment
        bus_path_2 = " " * len(fixed_path_segment) + fixed_path_segment[:5] + car_emoji + fixed_path_segment[5:]
        bus_path_3 = " " * len(fixed_path_segment) + fixed_path_segment + fixed_path_segment[:5] + car_emoji
        bus_path_4 = " " * len(fixed_path_segment) + car_emoji + fixed_path_segment + fixed_path_segment

    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (bus_path_1 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (bus_path_2 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (bus_path_3 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (bus_path_4 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    print(f"Throughput: {passengers_transported / trip_number:.2f} passengers per trip")
    print()
    # Simulate the return of the bus
    time.sleep(0.25)
    clear_output(wait=True)
    if lane == 0:
        return_path_1 = fixed_path_segment + car_emoji + fixed_path_segment + fixed_path_segment
        return_path_2 = fixed_path_segment + fixed_path_segment[:5] + car_emoji + fixed_path_segment[5:]
        return_path_3 = fixed_path_segment[:5] + car_emoji + fixed_path_segment + fixed_path_segment[5:]
        return_path_4 = car_emoji + fixed_path_segment + fixed_path_segment + fixed_path_segment
    else:
        return_path_1 = " " * len(fixed_path_segment) + fixed_path_segment + car_emoji + fixed_path_segment
        return_path_2 = " " * len(fixed_path_segment) + fixed_path_segment[:5] + car_emoji + fixed_path_segment[5:]
        return_path_3 = " " * len(fixed_path_segment) + fixed_path_segment + fixed_path_segment[:5] + car_emoji
        return_path_4 = " " * len(fixed_path_segment) + car_emoji + fixed_path_segment + fixed_path_segment

    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (return_path_1 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (return_path_2 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (return_path_3 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    time.sleep(0.25)
    clear_output(wait=True)
    print(f"Trip {trip_number}: {passengers_transported} passengers transported by {car_emoji}.")
    for row in range(2):
        print(start_smileys[row] + "  " + (return_path_4 if row == lane else " " * (3 * len(fixed_path_segment) + 1)) + "  " + stop_smileys[row])
    print(f"Throughput: {passengers_transported / trip_number:.2f} passengers per trip")
    print()

# Create and start threads for two cars in different lanes
car1 = threading.Thread(target=transport_passengers, args=(1, "🚗", 0))
car2 = threading.Thread(target=transport_passengers, args=(2, "🚙", 1, 0.5))

car1.start()
car2.start()

car1.join()
car2.join()
# Out:
# Trip 7: 7 passengers transported by 🚗.
# 😃😃😃⬜⬜  -----🚗---------------  😃😃😃😃😃
# ⬜⬜⬜⬜⬜                                   😃😃⬜⬜⬜
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-da4f6292047a> in <cell line: 120>()
#     118 car2.start()
#     119
# --> 120 car1.join()
#     121 car2.join()
#
# /usr/lib/python3.10/threading.py in join(self, timeout)
#    1094
#    1095         if timeout is None:
# -> 1096             self._wait_for_tstate_lock()
#    1097         else:
#    1098             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.10/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1114
#    1115         try:
# -> 1116             if lock.acquire(block, timeout):
#    1117                 lock.release()
#    1118                 self._stop()
#
# KeyboardInterrupt:
